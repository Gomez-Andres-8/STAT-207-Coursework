# %% [markdown]
# # STAT 207 Homework 12 [25 points]
#
# ## Regularization Models for Linear Relationships

# %% [markdown]
# Due: Wednesday, May 1, end of day (11:59 pm CT)
#
# <hr>

# %% [markdown]
# ## Imports
#
# Run the following code cell to import the necessary packages into the file.  You may import additional packages, as needed for this assignment.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ## The Data
#
# With available climate data dating back many decades and the prevalence of climate change, humans are looking to understand exactly how different features of the climate affect the temperatures globally.  For this assignment, we will look to understand how the **global temperature** fluctuates based on other environmental features.
#
# We will use various atmospheric and temperature measures over 309 months from 1983 to 2008, with the following variables:
#
# - **Year**: the observation year
# - **Month**: the observation month, recorded with numbers 1 to 12
# - **MEI**: Multivariate El Nino Southern Oscillation Index (MEI), measuring the affects of the El Nino weather pattern
# - **CO2**: atmospheric concentration of carbon dioxide (in ppmv, parts per million by volume)
# - **CH4**: atmospheric concentration of methane (in ppmv)
# - **N2O**: atmospheric concentration of nitrous oxide (in ppmv)
# - **CFC-11**: atmospheric concentration of CCl3F or trichlorofluoromethane (in ppbv, parts per billion by volume)
# - **CFC-12**: atmospheric concentration of CCl2F2 or dichlorodifluoromethane (in ppbv)
# - **TSI**: the total solar irradiance (TSI) (in W/m2), measuring the rate at which the sun's energy is deposited per unit area.
# - **Aerosols**: the mean stratospheric aerosol optical depth at 500 nm, a measure associated with volcanic activity
# - **Temp**: the difference in the average global temperature for that month (in Celsius) and a reference value
#
# The ESRL/NOAA Physical Sciences Division reports the MEI; atmospheric concentrations are measured by the ESRL/NOAA Global Monitoring Division; the SOLARIS-HEPPA project website provides the TSI; the Godard Institute for Space Studies at NASA reports the Aerosols; and the Climatic Research Unit at the University of East Anglia reports the Temp.
#
# Run the code in the cell below to read in the cleaned data for this document.  The data is saved as `df` with this code.

# %%
df = pd.read_csv('climate_change.csv')
df_train = df[df['Year'] <= 2006]
df_test = df[df['Year'] >= 2007]
X_train = df_train.drop(['Year', 'Month', 'Temp'], axis = 1)
X_test = df_test.drop(['Year', 'Month', 'Temp'], axis = 1)
y_train = df_train['Temp']
y_test = df_test['Temp']

# %% [markdown]
# ## 1. Summarize Data [2 points]
#
# Above, we set aside a training data.  We didn't randomly select our training and test set; instead, we imagine that we fit a model using the available data in 2006 in our training data.  We'll then use the following data from the months from 2007 and 2008 as the test set.
#
# As defined in our X_train and X_test above, our response variable for this assignment with be **Temp**.  We'll use all variables except the **Year** and **Month** as our predictor variables.

# %% [markdown]
# **a)** First, let's explore the summary statistics between our predictor variables.

# %%
X_train.describe()
# Out:
#               MEI         CO2          CH4         N2O      CFC-11  \
# count  284.000000  284.000000   284.000000  284.000000  284.000000
# mean     0.341923  361.414261  1745.841479  311.657225  252.487092
# std      0.929639   11.439691    45.669846    4.758513   20.987671
# min     -1.586000  340.170000  1629.890000  303.677000  191.324000
# 25%     -0.323000  352.315000  1716.347500  307.657000  249.557750
# 50%      0.308500  359.890000  1758.605000  310.849500  260.373500
# 75%      0.898000  370.585000  1781.637500  316.129250  267.448000
# max      3.001000  384.980000  1808.150000  320.451000  271.494000
#
#            CFC-12          TSI    Aerosols
# count  284.000000   284.000000  284.000000
# mean   494.217546  1366.101437    0.017721
# std     59.046642     0.401283    0.030014
# min    350.113000  1365.426100    0.001600
# 25%    462.543000  1365.754550    0.002700
# 50%    522.089000  1366.054500    0.006200
# 75%    540.972750  1366.399275    0.014000
# max    543.813000  1367.316200    0.149400

# %% [markdown]
# **b)** Scale our predictor variables in the training data.  Then, observe the summary statistics for the variables in the training data.

# %%
scaler_training = StandardScaler()
scaled_expl_vars = scaler_training.fit_transform(X_train)
X_train = pd.DataFrame(scaled_expl_vars, columns=X_train.columns)
X_train.describe()
# Out:
#                 MEI           CO2           CH4           N2O        CFC-11  \
# count  2.840000e+02  2.840000e+02  2.840000e+02  2.840000e+02  2.840000e+02
# mean   3.752867e-17  2.501911e-15  2.301758e-15 -2.001529e-16 -1.150879e-15
# std    1.001765e+00  1.001765e+00  1.001765e+00  1.001765e+00  1.001765e+00
# min   -2.077501e+00 -1.860344e+00 -2.543388e+00 -1.680002e+00 -2.919383e+00
# 25%   -7.165109e-01 -7.968154e-01 -6.469486e-01 -8.421301e-01 -1.398208e-01
# 50%   -3.601564e-02 -1.334784e-01  2.799670e-01 -1.700429e-01  3.764272e-01
# 75%    5.992210e-01  8.030748e-01  7.851835e-01  9.414536e-01  7.141010e-01
# max    2.865383e+00  2.063634e+00  1.366734e+00  1.851271e+00  9.072212e-01
#
#              CFC-12           TSI    Aerosols
# count  2.840000e+02  2.840000e+02  284.000000
# mean   2.501911e-16 -4.336813e-13    0.000000
# std    1.001765e+00  1.001765e+00    1.001765
# min   -2.444829e+00 -1.685916e+00   -0.538056
# 25%   -5.373796e-01 -8.659712e-01   -0.501341
# 50%    4.728576e-01 -1.171738e-01   -0.384524
# 75%    7.932329e-01  7.435250e-01   -0.124187
# max    8.414196e-01  3.032543e+00    4.394997

# %% [markdown]
# **c)** Now, we want to be sure that we also scale our test data according to the same process.  Apply your scaling algorithm from **part b** to the test data.  Observe the means and variances of your scaled test data.
#
# *Note*: This does not include re-fitting your scaling process.  You will re-use your scaling process from **part b**.

# %%
scaled_expl_vars = scaler_training.transform(X_test)
X_test = pd.DataFrame(scaled_expl_vars, columns=X_test.columns)
X_test.describe()
# Out:
#              MEI        CO2        CH4        N2O     CFC-11     CFC-12  \
# count  24.000000  24.000000  24.000000  24.000000  24.000000  24.000000
# mean   -0.917795   2.036889   1.121218   1.984680  -0.314865   0.720071
# std     0.690182   0.179041   0.250031   0.114226   0.065486   0.024218
# min    -2.130303   1.706352   0.571373   1.826219  -0.401280   0.690306
# 25%    -1.493181   1.895939   1.020765   1.873744  -0.375720   0.693835
# 50%    -0.940110   2.023790   1.145081   2.020740  -0.301021   0.725222
# 75%    -0.407244   2.164996   1.265504   2.052897  -0.281332   0.732229
# max     0.681118   2.371878   1.499001   2.215683  -0.196418   0.763259
#
#              TSI   Aerosols
# count  24.000000  24.000000
# mean   -0.982834  -0.455588
# std     0.079206   0.020206
# min    -1.109496  -0.487991
# 25%    -1.064123  -0.471303
# 50%    -0.965827  -0.454614
# 75%    -0.936619  -0.441264
# max    -0.848371  -0.411225

# %%
X_train.corr()
# Out:
#                MEI       CO2       CH4       N2O    CFC-11    CFC-12  \
# MEI       1.000000 -0.041147 -0.033419 -0.050820  0.069000  0.008286
# CO2      -0.041147  1.000000  0.877280  0.976720  0.514060  0.852690
# CH4      -0.033419  0.877280  1.000000  0.899839  0.779904  0.963616
# N2O      -0.050820  0.976720  0.899839  1.000000  0.522477  0.867931
# CFC-11    0.069000  0.514060  0.779904  0.522477  1.000000  0.868985
# CFC-12    0.008286  0.852690  0.963616  0.867931  0.868985  1.000000
# TSI      -0.154492  0.177429  0.245528  0.199757  0.272046  0.255303
# Aerosols  0.340238 -0.356155 -0.267809 -0.337055 -0.043921 -0.225131
#
#                TSI  Aerosols
# MEI      -0.154492  0.340238
# CO2       0.177429 -0.356155
# CH4       0.245528 -0.267809
# N2O       0.199757 -0.337055
# CFC-11    0.272046 -0.043921
# CFC-12    0.255303 -0.225131
# TSI       1.000000  0.052117
# Aerosols  0.052117  1.000000

# %%
sns.heatmap(X_train.corr(),vmin=-1, vmax=1, cmap='RdBu')
plt.show()

# %% [markdown]
# ## 2. Fitting A Model [1 point]
#
# Fit a LASSO model with $\lambda = 0.06$ to the training data, including all variables except the year and month variables.  Print the coefficients for this model.

# %%
lasso_mod_06 = Lasso(alpha=.06, max_iter=1000)
lasso_mod_06.fit(X_train, y_train)
# Out:
# Lasso(alpha=0.06)

# %%
lasso_mod_10 = Lasso(alpha=10, max_iter=1000)
lasso_mod_10.fit(X_train, y_train)
# Out:
# Lasso(alpha=10)

# %%
df_slopes = pd.DataFrame({'lass_mod_06' : lasso_mod_06.coef_, 'lass_mod_10' : lasso_mod_10.coef_}, index = X_train.columns)
df_slopes
# Out:
#           lass_mod_06  lass_mod_10
# MEI          0.000000          0.0
# CO2          0.079893          0.0
# CH4          0.000000          0.0
# N2O          0.002758          0.0
# CFC-11       0.000000          0.0
# CFC-12       0.000000          0.0
# TSI          0.000000          0.0
# Aerosols    -0.000000         -0.0

# %% [markdown]
# ## 3. Picking a Best Model [2 points]
#
# Let's suppose that we decide to move forward with a ridge regression model.  We originally fit the model with $\lambda = 0.06$.  Let's explore whether this value of $\lambda$ is the best for our model.
#
# To do this, we'll explore $\lambda$ values between 0.05 and 1 exploring by every 0.05.  We can do this with code using:
#
# `for m in range(1, 21):`
#
# `alph = m / 20`
#
# The following code sets up the folds for cross-validation.

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score

cross_val = KFold(n_splits = 10, shuffle = True, random_state = 202405)

# %% [markdown]
# **a)** Use 10-fold cross-validation to explore the $R^2$ values for each of the $\lambda$s as defined above.

# %%
X=df.drop(['Year', 'Month', 'Temp'], axis=1)
y=df['Temp']
scaler_full = StandardScaler()
scaled_expl_vars = scaler_full.fit_transform(X)
X = pd.DataFrame(scaled_expl_vars, columns=X.columns)

# %%
fold_10_1 = []
for m in range(1, 21):
    alph = m / 20
    model = Ridge(alpha = alph, max_iter=1000)
    test_fold_r2 = cross_val_score(model, X_train, y_train, cv=cross_val, scoring="r2")
    d = {'alpha' : alph, 'mean_r2' : test_fold_r2.mean()}
    fold_10_1.append(d)
fold_10_1 = pd.DataFrame(fold_10_1)

# %%
fold_10_1
# Out:
#     alpha   mean_r2
# 0    0.05  0.729396
# 1    0.10  0.729478
# 2    0.15  0.729529
# 3    0.20  0.729554
# 4    0.25  0.729557
# 5    0.30  0.729542
# 6    0.35  0.729513
# 7    0.40  0.729472
# 8    0.45  0.729421
# 9    0.50  0.729363
# 10   0.55  0.729298
# 11   0.60  0.729228
# 12   0.65  0.729154
# 13   0.70  0.729077
# 14   0.75  0.728998
# 15   0.80  0.728917
# 16   0.85  0.728834
# 17   0.90  0.728751
# 18   0.95  0.728668
# 19   1.00  0.728584

# %% [markdown]
# **b)** Print the $R^2$ values for each of the individual folds of your optimal $\lambda$.

# %%
alph = fold_10_1.nlargest(1, columns = ['mean_r2'])['alpha'].iloc[0]
model = Ridge(alpha = alph, max_iter=1000)
cross_val = KFold(n_splits = 10, shuffle = True, random_state = 207)
test_fold_1 = cross_val_score(model, X_train, y_train, cv=cross_val, scoring="r2")
print('Optimal Test Fold lambda:', fold_10_1.nlargest(1, columns = ['mean_r2'])['alpha'].iloc[0])
print('Optimal Test Fold R^2 Values:', test_fold_1)
# Out:
# Optimal Test Fold lambda: 0.25
# Optimal Test Fold R^2 Values: [0.69997365 0.69659443 0.73850739 0.86106287 0.70570187 0.82259746
#  0.73455882 0.75257381 0.59377616 0.63236478]

# %%
print('Optimal Test Fold R^2 Minimum Fold:', test_fold_1.min())
print('Optimal Test Fold R^2 Maximum Fold:', test_fold_1.max())
# Out:
# Optimal Test Fold R^2 Minimum Fold: 0.5937761572569096
# Optimal Test Fold R^2 Maximum Fold: 0.861062872276541

# %% [markdown]
# **c)** Repeat this process for a different set of 10-folds, using a random state of your choosing.  Determine which $\lambda$ results in the optimal mean $R^2$, similar to what you did above.

# %%
fold_10_2 = []
for m in range(1, 21):
    alph = m / 20
    model = Ridge(alpha = alph, max_iter=1000)
    cross_val = KFold(n_splits = 10, shuffle = True, random_state = 207)
    test_fold_r2 = cross_val_score(model, X_train, y_train, cv=cross_val, scoring="r2")
    d = {'alpha' : alph, 'mean_r2' : test_fold_r2.mean()}
    fold_10_2.append(d)
fold_10_2 = pd.DataFrame(fold_10_2)
alph = fold_10_2.nlargest(1, columns = ['mean_r2'])['alpha'].iloc[0]
model = Ridge(alpha = alph, max_iter=1000)
cross_val = KFold(n_splits = 10, shuffle = True, random_state = 207)
test_fold_2 = cross_val_score(model, X_train, y_train, cv=cross_val, scoring="r2")
print('Optimal Test Fold lambda:', fold_10_2.nlargest(1, columns = ['mean_r2'])['alpha'].iloc[0])
print('Optimal Test Fold R^2 Values:', test_fold_2)
# Out:
# Optimal Test Fold lambda: 0.4
# Optimal Test Fold R^2 Values: [0.69784329 0.70257225 0.73516575 0.86081035 0.70723132 0.82350735
#  0.73437134 0.75145901 0.59495645 0.63028517]

# %% [markdown]
# ## 4. Evaluating Our Best Model [1.5 points]
#
# **a)** Refit the model with the optimal $\lambda$ found in Question 3 to the full training data.  Then, print the resulting coefficients.

# %%
final_model = Ridge(alpha = 0.25, max_iter = 1000).fit(X, y)
df_slopes = pd.DataFrame(final_model.coef_.T, columns = ['final_model'], index = X.columns)
df_slopes
# Out:
#           final_model
# MEI          0.062344
# CO2          0.063598
# CH4          0.003673
# N2O         -0.072162
# CFC-11      -0.132830
# CFC-12       0.222095
# TSI          0.038164
# Aerosols    -0.046313

# %% [markdown]
# **b)** Calculate the $R^2$ on the test data for the model fit in **4a**.

# %%
final_model.score(X, y)
# Out:
# 0.7437756013364407

# %% [markdown]
# Remember to keep all your cells and hit the save icon above periodically to checkpoint (save) your results on your local computer. Once you are satisified with your results restart the kernel and run all (Kernel -> Restart & Run All). **Make sure nothing has changed**. Checkpoint and exit (File -> Save and Checkpoint + File -> Close and Halt). Follow the instructions on the Homework 12 Canvas Assignment to submit your notebook to GitHub.
